# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

from src.feature_engineering import add_loan_features

# %%
import pandas as pd
df = pd.read_csv('../data/processed/cleaned_loan_data_capped.csv')

# %%
df = add_loan_features(df)
df.describe(include='all')
# Out:
#        ID number  Personnel Number  Basic Salary       Payment  AFFORDABILITY  \
# count      17719      17719.000000  17718.000000  17719.000000   17718.000000
# unique     17719               NaN           NaN           NaN            NaN
# top     ID_20875               NaN           NaN           NaN            NaN
# freq           1               NaN           NaN           NaN            NaN
# mean         NaN     230407.285569   6504.516945   4478.823803    1739.543527
# std          NaN     122276.375727    827.967233   1955.077968    1749.869182
# min          NaN          5.000000   5129.945000   1353.340000   -2419.440000
# 25%          NaN     121912.000000   6114.830000   2910.460000     318.344500
# 50%          NaN     242040.000000   6595.920000   3917.560000    1114.457000
# 75%          NaN     337581.000000   6771.420000   5578.380000    2773.453000
# max          NaN     438575.000000   7756.305000   9580.260000    6456.115750
#
# ...

# %%
df.to_csv('../data/processed/loan_data_features.csv', index=False)
